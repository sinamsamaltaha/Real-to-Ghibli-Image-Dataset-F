# %% [markdown]
# <a href="https://colab.research.google.com/github/sinamsamaltaha/Real-to-Ghibli-Image-Dataset-F/blob/main/Another_copy_of_now.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # Load the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
mydata = pd.read_csv('/content/drive/MyDrive/ai_ghibli_trend_dataset_v2.csv')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mydata.tail(5)
# Out:
#                                  image_id   user_id  \
# 495  135267ba-3941-42ae-a421-3be20e3856d1  c80e6866
# 496  b2ced831-5b08-403d-bfb3-b562e256f359  81669630
# 497  8c87b8aa-b304-43cf-82b3-3a199367ec17  258613ea
# 498  04dba0f4-fdb7-4341-8bb6-dca5a595cd81  23b56439
# 499  1960cd2d-0e99-4e09-b426-62212dd8b37f  7dea460a
#
#                                                 prompt  likes  shares  \
# 495  Anime-style train passing through a fantasy world   1634    1328
# 496          Serene meadow with a tiny spirit creature   4198     833
# 497        Ghibli-style mountain with floating islands   1237    1703
# 498     Cozy tea shop in a mystical town, Ghibli style   1852    1158
# 499       Mysterious temple hidden in a magical forest   3944    1059
#
#      comments platform  generation_time  gpu_usage  file_size_kb resolution  \
# 495       624   TikTok            10.56         73          3255  1024x1024
# ...

# %%
mydata = pd.read_csv('/content/drive/MyDrive/ai_ghibli_trend_dataset_v2.csv')

# %%
# mydata.head()
# mydata.columns
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   image_id               500 non-null    object
#  1   user_id                500 non-null    object
#  2   prompt                 500 non-null    object
#  3   likes                  500 non-null    int64
#  4   shares                 500 non-null    int64
#  5   comments               500 non-null    int64
#  6   platform               500 non-null    object
#  7   generation_time        500 non-null    float64
#  8   gpu_usage              500 non-null    int64
#  9   file_size_kb           500 non-null    int64
#  10  resolution             500 non-null    object
#  11  style_accuracy_score   500 non-null    int64
#  12  is_hand_edited         500 non-null    object
#  13  ethical_concerns_flag  500 non-null    object
# ...

# %%
mydata.describe()
# Out:
#              likes       shares    comments  generation_time   gpu_usage  \
# count   500.000000   500.000000  500.000000       500.000000  500.000000
# mean   2601.262000  1040.182000  506.872000         8.317780   61.124000
# std    1429.433498   562.668738  283.384066         3.903103   18.151131
# min     105.000000    13.000000    5.000000         1.540000   30.000000
# 25%    1343.500000   587.750000  276.750000         5.027500   45.000000
# 50%    2566.500000  1092.000000  518.000000         8.380000   63.000000
# 75%    3913.250000  1502.000000  744.250000        11.540000   77.000000
# max    4944.000000  1999.000000  998.000000        14.990000   90.000000
#
#        file_size_kb  style_accuracy_score
# count    500.000000            500.000000
# mean    2511.822000             74.626000
# std     1390.178578             14.679001
# min      101.000000             50.000000
# 25%     1374.750000             62.000000
# 50%     2498.000000             74.000000
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="image_id", y="user_id", data=mydata)
# Out:
# <Axes: xlabel='image_id', ylabel='user_id'>

# %%
pd.crosstab(mydata['prompt'],mydata['image_id'] )
# Out:
# image_id                                           00255782-9630-4541-833b-ad3131750695  \
# prompt
# A lone traveler exploring an enchanted ruin                                           0
# Anime-style train passing through a fantasy world                                     0
# Cozy tea shop in a mystical town, Ghibli style                                        0
# Ghibli-style mountain with floating islands                                           0
# Ghibli-style night sky with glowing stars                                             0
# Ghibli-style village at sunset                                                        0
# Magical Ghibli forest with floating lanterns                                          0
# Mysterious castle in the clouds, Ghibli-style                                         0
# Mysterious temple hidden in a magical forest                                          0
# ...

# %%
pd.crosstab(mydata['prompt'],mydata['platform'] )
# Out:
# platform                                           Instagram  Reddit  TikTok  \
# prompt
# A lone traveler exploring an enchanted ruin               14       9       9
# Anime-style train passing through a fantasy world         14      10      16
# Cozy tea shop in a mystical town, Ghibli style             9       7      12
# Ghibli-style mountain with floating islands                9       8      14
# Ghibli-style night sky with glowing stars                  5      12      12
# Ghibli-style village at sunset                            11       5       9
# Magical Ghibli forest with floating lanterns               8      11       8
# Mysterious castle in the clouds, Ghibli-style             11      16      12
# Mysterious temple hidden in a magical forest               9      11       6
# Serene meadow with a tiny spirit creature                  8      11       6
# Spirited Away-style bustling market street                12       6       8
# ...

# %%
sns.countplot(x="image_id", hue="prompt", data=mydata)
# Out:
# <Axes: xlabel='image_id', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['prompt', 'image_id'],
                     columns=[ 'platform'], aggfunc=len)
# Out:
#                                                                                    comments  \
# platform                                                                          Instagram
# prompt                                       image_id
# A lone traveler exploring an enchanted ruin  08ff6f78-4bd7-4fd8-ba3f-f89d1ae95155       NaN
#                                              0cf34c49-6f55-4ce8-ab17-2b62f90b954c       1.0
#                                              102c8d4d-38db-41bc-89d9-1d64a70718e0       NaN
#                                              10a744e7-6591-481e-aa54-09bcae2f0392       NaN
#                                              1f9eb356-5963-4e2b-b145-adc86ab0bc19       NaN
# ...                                                                                     ...
# Studio Ghibli-inspired ocean with giant fish e7a1b91f-384a-4870-8e02-c9ca2a217bc3       NaN
#                                              ec86ee15-fe2b-4ddd-a722-b0682a24ef28       1.0
# ...

# %%
pd.pivot_table(mydata,'likes', index=['prompt', 'image_id'],
                     columns=[ 'platform'])
# Out:
# platform                                                                           Instagram  \
# prompt                                       image_id
# A lone traveler exploring an enchanted ruin  08ff6f78-4bd7-4fd8-ba3f-f89d1ae95155        NaN
#                                              0cf34c49-6f55-4ce8-ab17-2b62f90b954c     2333.0
#                                              102c8d4d-38db-41bc-89d9-1d64a70718e0        NaN
#                                              10a744e7-6591-481e-aa54-09bcae2f0392        NaN
#                                              1f9eb356-5963-4e2b-b145-adc86ab0bc19        NaN
# ...                                                                                      ...
# Studio Ghibli-inspired ocean with giant fish e7a1b91f-384a-4870-8e02-c9ca2a217bc3        NaN
#                                              ec86ee15-fe2b-4ddd-a722-b0682a24ef28     3574.0
# ...

# %%
mydata['likes'].std()
# Out:
# 1429.4334981408595

# %%
mydata['likes'].mean()
# Out:
# np.float64(2601.262)

# %%
sns.displot(mydata['likes'])

# %%
sns.pairplot(mydata)

# %%
mydata.hist(by='prompt',column = 'shares')
plt.show()

# %%
mydata.hist(by='prompt',column = 'is_hand_edited')
# Out:
# array([[<Axes: title={'center': 'A lone traveler exploring an enchanted ruin'}>,
#         <Axes: title={'center': 'Anime-style train passing through a fantasy world'}>,
#         <Axes: title={'center': 'Cozy tea shop in a mystical town, Ghibli style'}>],
#        [<Axes: title={'center': 'Ghibli-style mountain with floating islands'}>,
#         <Axes: title={'center': 'Ghibli-style night sky with glowing stars'}>,
#         <Axes: title={'center': 'Ghibli-style village at sunset'}>],
#        [<Axes: title={'center': 'Magical Ghibli forest with floating lanterns'}>,
#         <Axes: title={'center': 'Mysterious castle in the clouds, Ghibli-style'}>,
#         <Axes: title={'center': 'Mysterious temple hidden in a magical forest'}>],
#        [<Axes: title={'center': 'Serene meadow with a tiny spirit creature'}>,
#         <Axes: title={'center': 'Spirited Away-style bustling market street'}>,
#         <Axes: title={'center': 'Studio Ghibli-inspired ocean with giant fish'}>]],
# ...

# %%
mydata.hist(by='prompt',column = 'gpu_usage')
plt.show()

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = mydata.likes

# %%
x[0:20]
# Out:
# 0      916
# 1     2965
# 2     4727
# 3     1629
# 4     2573
# 5     3715
# 6     2334
# 7     1947
# 8     1851
# 9     4192
# 10    3451
# 11    4170
# 12    2163
# 13    4764
# 14    3734
# 15    2337
# 16    1279
# 17    2460
# 18    3972
# 19    2332
# Name: likes, dtype: int64

# %%
fig, ax = plt.subplots()
_=plt.hist(x, color='#31708F' ) # create histogram for X varaible (likes)

# %%
xbar = x.mean()
xbar
# Out:
# np.float64(2601.262)

# %%
np.median(x)
# Out:
# np.float64(2566.5)

# %%
plt.axvline(x = x.mean(), #show mean
            color='pink')
_ = plt.hist(x, color = 'gray')

# %%
fig, ax = plt.subplots()
plt.axvline(x = np.mean(x), color='pink')
plt.axvline(x = np.median(x), color='red')
_ = plt.hist(x, color = 'gray')

# %%
x.std()
# Out:
# 1429.4334981408595

# %%
x.mean()
# Out:
# np.float64(2601.262)

# %%
x_sample = np.random.choice(x, size=10, replace=False)

# %%
x_sample
# Out:
# array([ 1.3000723 ,  0.39101148,  1.57787092,  0.84228277,  0.44460171,
#         1.84815472,  0.27851056, -0.03258686,  1.124949  ,  0.42294231])

# %%
x.var()
# Out:
# 2043280.1256072142

# %%
x.var()**(1/2) # calculate the std of the varience
# Out:
# 1429.4334981408595

# %%
sigma = x.std()
sigma
# Out:
# 1429.4334981408595

# %%
fig, ax = plt.subplots()
plt.axvline(x = xbar, color='pink') # mean
plt.axvline(x = xbar+sigma, color='red') # xbar
plt.axvline(x = xbar-sigma, color='red') # sigma
_ = plt.hist(x, color = 'gray')

# %%
sigma/(x.size)**(1/2)
# Out:
# np.float64(0.044056229104957365)

# %%
x = mydata.likes

# %%
x = np.random.normal(size=10000)

# %%
sns.set_style('ticks')

# %%
_ = sns.displot(x, kde=True)

# %%
x.mean()
# Out:
# np.float64(-0.0009253998734883574)

# %%
x.std()
# Out:
# np.float64(0.9902076674369001)

# %%
x_sample = np.random.choice(x, size=10, replace=True)
x_sample
# Out:
# array([-0.4658558 ,  0.38166487, -0.15169104, -0.9183059 ,  0.7089514 ,
#         1.10059667, -1.81779995, -0.98788674,  1.7744184 , -0.60911694])

# %%
x_sample.mean()
# Out:
# np.float64(0.10757683901488188)

# %%
def sample_mean_calculator(input_dist, sample_size, n_samples):
    sample_means = []
    for i in range(n_samples):
        sample = np.random.choice(input_dist, size=sample_size, replace=False)
        sample_means.append(sample.mean())
    return sample_means

# %%
sns.displot(sample_mean_calculator(x, 10, 10), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
sns.displot(sample_mean_calculator(x, 10, 1000), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
sns.displot(sample_mean_calculator(x, 100, 1000), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
sns.displot(sample_mean_calculator(x, 1000, 1000), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
s = st.skewnorm.rvs(10, size=10000)

# %%
_ = sns.displot(s, kde=True)

# %%
_ = sns.displot(sample_mean_calculator(s, 10, 1000), color='green', kde=True)

# %%
_ = sns.displot(sample_mean_calculator(s, 1000, 1000), color='green', kde=True)

# %%
m = np.concatenate((np.random.normal(size=5000), np.random.normal(loc = 4.0, size=5000)))

# %%
_ = sns.displot(m, kde=True)

# %%
_ = sns.displot(sample_mean_calculator(m, 1000, 1000), color='green', kde=True)

# %%
u = np.random.uniform(size=10000)

# %%
_ = sns.displot(u)

# %%
_ = sns.displot(sample_mean_calculator(u, 1000, 1000), color='green', kde=True)

# %%
x_i = 85
mu = 60
sigma = 10

# %%
x = np.random.normal(mu, sigma, 10000)

# %%
sns.displot(x, color='gray')
ax.set_xlim(0, 100)
plt.axvline(mu, color='pink')
for v in [-3, -2, -1, 1, 2, 3]:
    plt.axvline(mu+v*sigma, color='red')
_ = plt.axvline(x_i, color='blue')

# %%
z = (x_i - mu)/sigma
z
# Out:
# 2.5

# %%
z = (x_i - np.mean(x))/np.std(x)
z
# Out:
# np.float64(2.5089093566153498)

# %%
len(np.where(x > 85)[0])
# Out:
# 65

# %%
100*69/10000
# Out:
# 0.69

# %%
np.percentile(x, 99)
# Out:
# np.float64(83.2520431609863)

# %%
mu = 90
sigma = 2

# %%
y = np.random.normal(mu, sigma, 10000)

# %%
sns.displot(y, color='gray')
plt.axvline(mu, color='pink')
for v in [-3, -2, -1, 1, 2, 3]:
    plt.axvline(mu+v*sigma, color='red')
_ = plt.axvline(x_i, color='blue')

# %%
z = (x_i - mu)/sigma
z
# Out:
# -2.5

# %%
z = (x_i - np.mean(y))/np.std(y)
z
# Out:
# np.float64(-2.505843031013127)

# %%
len(np.where(y > 85)[0])
# Out:
# 9939

# %%
100*9933/10000
# Out:
# 99.33

# %%
10000-9933
# Out:
# 67

# %%
np.percentile(y, 1)
# Out:
# np.float64(85.36068870018737)

# %%
p_below = st.norm.cdf(-2.5)
p_below
# Out:
# np.float64(0.006209665325776132)

# %%
p_below*10000
# Out:
# np.float64(62.096653257761325)

# %%
sns.displot(y, color='gray')
_ = plt.axvline(mu-2.5*sigma, color='purple')

# %%
st.norm.cdf(2.5)
# Out:
# np.float64(0.9937903346742238)

# %%
p_above = 1-st.norm.cdf(2.5)
p_above
# Out:
# np.float64(0.006209665325776159)

# %%
p_above*10000
# Out:
# np.float64(62.09665325776159)

# %%
sns.displot(y, color='gray')
_ = plt.axvline(mu+2.5*sigma, color='purple')

# %%
p_outside = p_below + p_above
p_outside
# Out:
# np.float64(0.01241933065155229)

# %%
p_outside*10000
# Out:
# np.float64(124.1933065155229)

# %%
sns.displot(y, color='gray')
plt.axvline(mu+2.5*sigma, color='purple')
_ = plt.axvline(mu-2.5*sigma, color='purple')

# %%
st.norm.ppf(.025)
# Out:
# np.float64(-1.9599639845400545)

# %%
st.norm.ppf(.975)
# Out:
# np.float64(1.959963984540054)

# %%
sns.displot(y, color='gray')
plt.axvline(mu+1.96*sigma, color='darkred')
_ = plt.axvline(mu-1.96*sigma, color='darkred')

# %%
st.norm.ppf(.005)
# Out:
# np.float64(-2.575829303548901)

# %%
st.norm.ppf(.995)
# Out:
# np.float64(2.5758293035489004)

# %%
sns.displot(y, color='gray')

plt.axvline(mu+1.96*sigma, color='darkred')
plt.axvline(mu-1.96*sigma, color='darkred')

plt.axvline(mu+2.56*sigma, color='black')
_ = plt.axvline(mu-2.56*sigma, color='black')

# %%
p_below = st.norm.cdf(0)
p_below
# Out:
# np.float64(0.5)

# %%
p_above = 1-st.norm.cdf(0)
p_above
# Out:
# np.float64(0.5)

# %%
p_below + p_above
# Out:
# np.float64(1.0)

# %%
def p_from_z(my_z):
    return 2 * st.norm.cdf(-abs(my_z))

# %%
p_from_z(0)
# Out:
# np.float64(1.0)

# %%
p_below = st.norm.cdf(-2)
p_below
# Out:
# np.float64(0.022750131948179195)

# %%
p_above = 1-st.norm.cdf(2)
p_above
# Out:
# np.float64(0.02275013194817921)

# %%
p_below + p_above
# Out:
# np.float64(0.0455002638963584)

# %%
p_from_z(2)
# Out:
# np.float64(0.04550026389635839)

# %%
p_from_z(4)
# Out:
# np.float64(6.334248366623973e-05)

# %%
0.0000633
# Out:
# 6.33e-05

# %%
-np.log10(6.33e-05)
# Out:
# np.float64(4.198596289982645)

# %%
x = [48, 50, 54, 60]

# %%
xbar = np.mean(x)
xbar
# Out:
# np.float64(53.0)

# %%
sx = st.sem(x)
sx
# Out:
# np.float64(2.6457513110645907)

# %%
t = (xbar-50)/sx
t
# Out:
# np.float64(1.1338934190276817)

# %%
def p_from_t(my_t, my_n):
    return 2 * st.t.cdf(-abs(my_t), my_n-1)

# %%
p_from_t(t, len(x))
# Out:
# np.float64(0.3392540508564543)

# %%
st.ttest_1samp(x, 50)
# Out:
# TtestResult(statistic=np.float64(1.1338934190276817), pvalue=np.float64(0.3392540508564543), df=np.int64(3))

# %%
penguins = sns.load_dataset('penguins').dropna() # some rows are missing data

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
np.unique(penguins.species, return_counts=True)
# Out:
# (array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object),
#  array([146,  68, 119]))

# %%
adelie = penguins[penguins.species == 'Adelie']

# %%
adelie
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
np.unique(adelie.island, return_counts=True)
# Out:
# (array(['Biscoe', 'Dream', 'Torgersen'], dtype=object), array([44, 55, 47]))

# %%
np.unique(adelie.sex, return_counts=True)
# Out:
# (array(['Female', 'Male'], dtype=object), array([73, 73]))

# %%
_ = sns.boxplot(x='island', y='body_mass_g', hue='sex', data=adelie)

# %%
f = adelie[adelie.sex == 'Female']['body_mass_g'].to_numpy()/1000
f
# Out:
# array([3.8  , 3.25 , 3.45 , 3.625, 3.2  , 3.7  , 3.45 , 3.325, 3.4  ,
#        3.8  , 3.8  , 3.2  , 3.15 , 3.25 , 3.3  , 3.325, 3.55 , 3.3  ,
#        3.15 , 3.1  , 3.   , 3.45 , 3.5  , 3.45 , 2.9  , 3.55 , 2.85 ,
#        3.15 , 3.6  , 2.85 , 3.35 , 3.05 , 3.6  , 3.55 , 3.7  , 3.7  ,
#        3.55 , 3.2  , 3.8  , 3.35 , 3.5  , 3.6  , 3.55 , 3.4  , 3.3  ,
#        3.7  , 2.9  , 3.725, 3.075, 2.925, 3.75 , 3.175, 3.825, 3.2  ,
#        3.9  , 2.9  , 3.35 , 3.15 , 3.45 , 3.05 , 3.275, 3.05 , 3.325,
#        3.5  , 3.425, 3.175, 3.4  , 3.4  , 3.05 , 3.   , 3.475, 3.45 ,
#        3.7  ])

# %%
m = adelie[adelie.sex == 'Male']['body_mass_g'].to_numpy()/1000
m
# Out:
# array([3.75 , 3.65 , 4.675, 3.8  , 4.4  , 4.5  , 4.2  , 3.6  , 3.95 ,
#        3.8  , 3.55 , 3.95 , 3.9  , 3.9  , 4.15 , 3.95 , 4.65 , 3.9  ,
#        4.4  , 4.6  , 3.425, 4.15 , 4.3  , 4.05 , 3.7  , 3.8  , 3.75 ,
#        4.4  , 4.05 , 3.95 , 4.1  , 4.45 , 3.9  , 4.15 , 4.25 , 3.9  ,
#        4.   , 4.7  , 4.2  , 3.55 , 3.8  , 3.95 , 4.3  , 4.45 , 4.3  ,
#        4.35 , 4.1  , 4.725, 4.25 , 3.55 , 3.9  , 4.775, 4.6  , 4.275,
#        4.075, 3.775, 3.325, 3.5  , 3.875, 4.   , 4.3  , 4.   , 3.5  ,
#        4.475, 3.9  , 3.975, 4.25 , 3.475, 3.725, 3.65 , 4.25 , 3.75 ,
#        4.   ])

# %%
fbar = f.mean()
fbar
# Out:
# np.float64(3.368835616438356)

# %%
mbar = m.mean()
mbar
# Out:
# np.float64(4.043493150684932)
